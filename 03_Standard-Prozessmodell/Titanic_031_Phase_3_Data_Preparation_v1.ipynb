# %% [markdown]
# ## Phase 3 (Data Preparation): v1

# %% [markdown]
# * Autorin: Anna (i3-Versicherung)
# * Webseite: [Data Science Training - Kapitel 3](https://data-science.training/kapitel-3/)
# * Datum: 23.03.2023

# %% [markdown]
# Wir bereiten die Daten für die nächsten Phasen vor. Dabei schätzen wir fehlenden Werte folgendermaßen ab:
#
# * Embarked: Modus
# * Fare: Medium
# * Age: Mittelwert
# * Cabin: 'Unknown' (als fester Wert)

# %%
# Pandas Paket (Package) importieren
#  Datenstrukturen und Datenanalyse, I/O
#  https://pandas.pydata.org/pandas-docs/stable/
import pandas as pd

# %%
# Trainings-, Test- und Anwendungsdaten als Pandas Data Frame (df) aus CSV-Dateien laden
#  (KNIME: "CSV Reader")
df_train = pd.read_csv('../../data/titanic/original/train.csv')
df_test  = pd.read_csv('../../data/titanic/original/test.csv')
df_app   = pd.read_csv('../../data/titanic/original/application.csv')

# %%
# Trainings- und Testdaten zusammenführen
#  (KNIME "Concatenate")
df = pd.concat([df_train, df_test], ignore_index=True)

# %%
# Datentypen automatisch konvertieren
df = df.convert_dtypes()

# %%
# Fehlende Werte prüfen
df.isnull().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
# Fehlende Werte behandeln
#  (KNIME: "Missing Values")
#
# Embarked (Nominalskala): 2 fehlende Werte => Benutze den Modus (häufigster Wert)
embarked_mode  = df['Embarked'].dropna().mode()[0]
df['Embarked'] = df['Embarked'].fillna(embarked_mode)
print('Embarked : ', embarked_mode)
#
# Fare (Kardinalskala): 1 fehlender Wert => Benutze den Median
fare_median = df['Fare'].dropna().median()
df['Fare']  = df['Fare'].fillna(fare_median)
print('Fare     : ', fare_median)
#
# Age (Kardinalskala): 263 fehlende Werte => Benutze den Mittelwert
age_mean  = df['Age'].dropna().mean()
df['Age'] = df['Age'].fillna(age_mean)
print('Age      : ', age_mean)
#
# Cabin (Nominalskala): 1014 fehlende Werte => Benutze den festen Wert 'Unknown'
cabin_fix = 'Unknown'
df['Cabin'] = df['Cabin'].fillna(cabin_fix)
print('Cabin    : ', cabin_fix)
# Out:
# Embarked :  S
# Fare     :  14.4542
# Age      :  29.881137667304014
# Cabin    :  Unknown

# %%
# Fehlende Werte prüfen
df.isnull().sum()
# Out:
# PassengerId      0
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin            0
# Embarked         0
# dtype: int64

# %%
# Daten wieder aufteilen
#  (KNIME: "Row Splitter")
df_train = df[df['Survived'].notna()]
df_test  = df[df['Survived'].isna()]

# %%
# Irrelevante Attribute filtern
#  (KNIME: "Column Filter")
#
# Trainingsdaten: PassengerId
df_train = df_train.drop(['PassengerId'], axis=1)
#
# Testdaten: Survived
df_test = df_test.drop(['Survived'], axis=1)

# %%
display(df_train)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex        Age  SibSp  Parch            Ticket     Fare    Cabin  \
# 0      male       22.0      1      0         A/5 21171     7.25  Unknown
# 1    female       38.0      1      0          PC 17599  71.2833      C85
# 2    female       26.0      0      0  STON/O2. 3101282    7.925  Unknown
# 3    female       35.0      1      0            113803     53.1     C123
# 4      male       35.0      0      0            373450     8.05  Unknown
# ..      ...        ...    ...    ...               ...      ...      ...
# 886    male       27.0      0      0            211536     13.0  Unknown
# 887  female       19.0      0      0            112053     30.0      B42
# 888  female  29.881138      1      2        W./C. 6607    23.45  Unknown
# 889    male       26.0      0      0            111369     30.0     C148
# 890    male       32.0      0      0            370376     7.75  Unknown
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# 886        S
# 887        S
# 888        S
# 889        C
# 890        Q
#
# [891 rows x 11 columns]

# %%
display(df_test)
# Out:
#       PassengerId  Pclass                                          Name  \
# 891           892       3                              Kelly, Mr. James
# 892           893       3              Wilkes, Mrs. James (Ellen Needs)
# 893           894       2                     Myles, Mr. Thomas Francis
# 894           895       3                              Wirz, Mr. Albert
# 895           896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ...           ...     ...                                           ...
# 1304         1305       3                            Spector, Mr. Woolf
# 1305         1306       1                  Oliva y Ocana, Dona. Fermina
# 1306         1307       3                  Saether, Mr. Simon Sivertsen
# 1307         1308       3                           Ware, Mr. Frederick
# 1308         1309       3                      Peter, Master. Michael J
#
#          Sex        Age  SibSp  Parch              Ticket     Fare    Cabin  \
# 891     male       34.5      0      0              330911   7.8292  Unknown
# 892   female       47.0      1      0              363272      7.0  Unknown
# 893     male       62.0      0      0              240276   9.6875  Unknown
# 894     male       27.0      0      0              315154   8.6625  Unknown
# 895   female       22.0      1      1             3101298  12.2875  Unknown
# ...      ...        ...    ...    ...                 ...      ...      ...
# 1304    male  29.881138      0      0           A.5. 3236     8.05  Unknown
# 1305  female       39.0      0      0            PC 17758    108.9     C105
# 1306    male       38.5      0      0  SOTON/O.Q. 3101262     7.25  Unknown
# 1307    male  29.881138      0      0              359309     8.05  Unknown
# 1308    male  29.881138      1      1                2668  22.3583  Unknown
#
#      Embarked
# 891         Q
# 892         S
# 893         Q
# 894         S
# 895         S
# ...       ...
# 1304        S
# 1305        C
# 1306        S
# 1307        S
# 1308        C
#
# [418 rows x 11 columns]

# %%
# Daten als Excel-Dateien speichern
#  (KNIME: "Excel Writer")
#
# Trainingsdaten
df_train.to_excel('../../data/titanic/new/training_v1.xlsx', index=False)
#
# Testdaten
df_test.to_excel('../../data/titanic/new/test_v1.xlsx', index=False)
#
# Anwendungsdaten
df_app.to_excel('../../data/titanic/new/application_v1.xlsx', index=False)
