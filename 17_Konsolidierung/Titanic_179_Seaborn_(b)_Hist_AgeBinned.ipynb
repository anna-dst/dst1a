# %% [markdown]
# ## Histogramm zu AgeBinned

# %% [markdown]
# * Autorin: Anna (i3-Versicherung)
# * Webseite: [Data Science Training - Kapitel 17](https://data-science.training/kapitel-17/)
# * Datum: 23.03.2023

# %% [markdown]
# mit Hilfe von Seaborn erstellen

# %%
# Pandas Paket (Package) importieren
#  Datenstrukturen und Datenanalyse, I/O
#  https://pandas.pydata.org/pandas-docs/stable/
import pandas as pd
# Matplot Bibliothek (Library) importieren
#  Mathematische grafische Daten-Visualisierungen
#  https://matplotlib.org/contents.html
import matplotlib.pyplot as plt
# Seaborn importieren [sns = seaborn name space, Samuel Norman Seaborn]
#  High-end Daten-Visualisierungen auf Basis von Matplot
#  https://seaborn.pydata.org/
import seaborn as sns
# Deutsches Zahlenformat
import locale
locale.setlocale(locale.LC_ALL, 'de')
# Warnungen unterdrücken
#import warnings
#warnings.filterwarnings('ignore')
# Out:
# 'de'

# %%
# Trainings- und Testdaten als Pandas Data Frame (df) aus Excel-Datei laden
#  (KNIME: "Excel Reader")
df_train = pd.read_excel('../../data/titanic/age/training_v2.xlsx')
df_test  = pd.read_excel('../../data/titanic/age/test_v2.xlsx')

# %%
# Daten zusammenführen
#  (KNIME "Concatenate")
df = pd.concat([df_train, df_test], ignore_index=True)

# %%
# Datentypen automatisch konvertieren
df_train = df_train.convert_dtypes()
df_test  = df_test.convert_dtypes()
df       = df.convert_dtypes()

# %%
# Daten vorbereiten (Sortierung!)
labels = ['Child', 'Teenage', 'Young', 'Adult', 'Middle', 'Senior']
df['AgeBinned'] = pd.Categorical(df['AgeBinned'], labels)

# %%
# Seaborn: Allgemeine Einstellungen

# Schriftart setzen
sns.set(font = 'Arial')
# Schriftgröße setzen
sns.set(font_scale = 2.5)
# Achsen im deutschen Zahlenformat
plt.rcParams['axes.formatter.use_locale'] = True
# Bildgröße setzen (16 x 9)
sns.set(rc={'figure.figsize':(8, 4.5)})
# Weißes Gitter setzen
sns.set_style('whitegrid')

# %%
# Histplot zu AgeBinned
# stat = density, count, percent
sns.histplot(df['AgeBinned'], kde=True, stat='count', kde_kws=dict(cut=3), alpha=.4, edgecolor=(1, 1, 1, .4))

# Achsen beschriften
plt.xlabel('Alter (AgeBinned)')
plt.ylabel('Häufigkeit')

# Grafik speichern
plt.savefig('../../figures/svg/Hist_AgeBinned.svg', format='svg', dpi=1200, transparent=True)
